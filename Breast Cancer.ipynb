# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seabors as sns

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold

# %matplotlib inline

# %%
features = ['radius','texture','perimeter','area',
                'smoothness','compactness','concavity',
                'concave_points','symmetry','fractal_dimension']

# %%
bcw_columns = ['id','clump_thickness','cell_size_uniformity',
           'cell_shape_uniformity','marginal_adhesion',
           'single_epithelial_cell_size',
           'bare_nuclei','bland_chromatin',
           'normal_nuclei','mitoses','class']

# %%
bcwDF = pd.read_csv('breast-cancer-wisconsin.data', names=bcw_columns)
bcwDF.head()
# Out:
#         id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0  1000025                5                     1                      1
# 1  1002945                5                     4                      4
# 2  1015425                3                     1                      1
# 3  1016277                6                     8                      8
# 4  1017023                4                     1                      1
#
#    marginal_adhesion  single_epithelial_cell_size bare_nuclei  \
# 0                  1                            2           1
# 1                  5                            7          10
# 2                  1                            2           2
# 3                  1                            3           4
# 4                  3                            2           1
#
#    bland_chromatin  normal_nuclei  mitoses  class
# 0                3              1        1      2
# 1                3              2        1      2
# ...

# %%
wdbc_columns = ['id', 'diagnosis']
wdbc_columns += [feature + '_mean' for feature in features]
wdbc_columns += [feature + '_se' for feature in features]
wdbc_columns += [feature + '_worst' for feature in features]

# %%
wdbcDF = pd.read_csv('wdbc.data', names=wdbc_columns)
wdbcDF.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
wpbc_columns = ['id', 'outcome','time']
wpbc_columns += [feature + '_mean' for feature in features]
wpbc_columns += [feature + '_se' for feature in features]
wpbc_columns += [feature + '_worst' for feature in features]
wpbc_columns += ['tumor_size','lymph_node_status']

# %%
wpbcDF = pd.read_csv('wpbc.data', names=wpbc_columns)
wpbcDF.head()
# Out:
#        id outcome  time  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  119513       N    31        18.02         27.60          117.50     1013.0
# 1    8423       N    61        17.99         10.38          122.80     1001.0
# 2  842517       N   116        21.37         17.44          137.50     1373.0
# 3  843483       N   123        11.42         20.38           77.58      386.1
# 4  843584       R    27        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean        ...          \
# 0          0.09489            0.1036          0.1086        ...
# 1          0.11840            0.2776          0.3001        ...
# 2          0.08836            0.1189          0.1255        ...
# 3          0.14250            0.2839          0.2414        ...
# 4          0.10030            0.1328          0.1980        ...
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# ...

# %%
wdbcDF.join(wpbcDF,on='id', how='inner', lsuffix='first')
# Out:
# Empty DataFrame
# ...
